# %%
from bokeh.io import output_notebook

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d4e9c1cb-c29d-43e4-a45b-d7e631f1e161">Loading BokehJS ...</span>
#     </div>

# %%
from impactchart.model import XGBoostImpactModel

from impactchart.backend.bokeh_backend import BokehBackend

import pandas as pd
import numpy as np

from bokeh.plotting import show

# %%
df_data = pd.DataFrame(
    {
        "x1": np.linspace(0, 100, 101),
    }
)

df_data["y"] = (
    np.sin(df_data["x1"] * 8.0 * np.pi / 100.0) + (df_data["x1"] - 50.0) / 25.0
)

df_data
# Out:
#         x1         y
# 0      0.0 -2.000000
# 1      1.0 -1.711310
# 2      2.0 -1.438246
# 3      3.0 -1.195453
# 4      4.0 -0.995672
# ..     ...       ...
# 96    96.0  0.995672
# 97    97.0  1.195453
# 98    98.0  1.438246
# 99    99.0  1.711310
# 100  100.0  2.000000
#
# [101 rows x 2 columns]

# %%
X = df_data[["x1"]]
y = df_data["y"]

# %%
impact_model = XGBoostImpactModel()

# %%
impact_model.fit(X, y)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %%
impact_model.charts(X);

# %%
bokeh_backend = BokehBackend()

# %%
charts = impact_model.charts(X, backend=bokeh_backend)

# %%
show(charts["x1"])
# Out:
#   <div id="ec09ae0d-aea4-4490-bb3f-07ed2b954537" data-root-id="p1001" style="display: contents;"></div>
